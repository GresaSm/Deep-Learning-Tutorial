# %% [markdown]
# <a href="https://colab.research.google.com/github/GresaSm/Deep-Learning-Tutorial/blob/main/Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install bertopic
# !pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.16.0-py2.py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.1/154.1 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.23.5)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 24.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Downloading umap-learn-0.5.5.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 11.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic) (4.66.1)
# Collecting sentence-transformers>=0.4.1 (from bertopic)
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic) (5.15.0)
# Collecting cython<3,>=0.27 (from hdbscan>=0.8.29->bertopic)
#   Using cached Cython-0.29.36-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.11.4)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic) (23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.35.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.16.0+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.8.1)
# Collecting sentencepiece (from sentence-transformers>=0.4.1->bertopic)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.4 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.19.4)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic) (0.58.1)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Downloading pynndescent-0.5.11-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.41.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.4.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.7)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039182 sha256=080c9dd1f635fe4a80d385ac85d37e9a7108b67dca139f49964b3fa389c9b6b4
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=4bb5dc6e1244faa492f1e6f421341f5fe7e9e0074ca3638844fa7fb8efb2aff9
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86832 sha256=52b5e4ead5219987d152f7449240e89ebef71ee7b705e0ae66d11d6d5712b34c
#   Stored in directory: /root/.cache/pip/wheels/3a/70/07/428d2b58660a1a3b431db59b806a10da736612ebbc66c1bcc5
# Successfully built hdbscan sentence-transformers umap-learn
# Installing collected packages: sentencepiece, cython, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.6
#     Uninstalling Cython-3.0.6:
#       Successfully uninstalled Cython-3.0.6
# Successfully installed bertopic-0.16.0 cython-0.29.36 hdbscan-0.8.33 pynndescent-0.5.11 sentence-transformers-2.2.2 sentencepiece-0.1.99 umap-learn-0.5.5

# %%
# Try to import BERTopic
from bertopic import BERTopic

# %%
# Install older version of joblib
# !pip install --upgrade joblib==1.1.0
# Out:
# Collecting joblib==1.1.0
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.0/307.0 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: joblib
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.3.2
#     Uninstalling joblib-1.3.2:
#       Successfully uninstalled joblib-1.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imbalanced-learn 0.10.1 requires joblib>=1.1.1, but you have joblib 1.1.0 which is incompatible.
# scikit-learn 1.2.2 requires joblib>=1.1.1, but you have joblib 1.1.0 which is incompatible.
# Successfully installed joblib-1.1.0

# %%
# Data processing
import pandas as pd
import numpy as np
import ast

# Text preprocessiong
import nltk
nltk.download('stopwords')
nltk.download('omw-1.4')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
import re

# Topic model
from bertopic import BERTopic

# Dimension reduction
from umap import UMAP
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_csv("preprocessed_subset_english_news.csv")

# keep only the text column
#df = df[['processed_text_v2', 'congress', 'period']]

# %%
df
# Out:
#                                                   title  \
# 0                        Vienna Jewish cemetery torched
# 1     Bill Ackman says it's 'pathetic' that law firm...
# 2     Netanyahu is focused on his own political 'sur...
# 3     Democrats sound alarms over No Labels third-pa...
# 4     Amid Hezbollah-Israel clashes, Christian villa...
# ...                                                 ...
# 4846  Europe’s COP 29 Climate Change Goals Should In...
# 4847  Joint statement by Joint Expeditionary Force m...
# 4848  Rapala VMC Corporation’s Financial Reporting i...
# 4849  Pharming Group (NASDAQ:PHAR) Shares Gap Down t...
# 4850  Aquis Exchange’s (AQX) “Buy” Rating Reiterated...
#
#                     published_at  category  \
# 0     2023-11-02 04:31:58.000000    Europe
# 1     2023-11-02 11:14:13.000000  Politics
# 2     2023-11-02 15:58:14.000000  Politics
# 3     2023-11-02 20:20:50.000000  Politics
# 4     2023-11-02 06:07:16.000000  Politics
# ...                          ...       ...
# 4846         2023-11-29 13:54:00    Europe
# 4847         2023-11-29 02:47:13    Europe
# 4848         2023-11-29 14:00:00    Europe
# 4849         2023-11-29 13:02:41    Europe
# 4850         2023-11-29 13:20:48    Europe
#
#                                            full_content  \
# 0     The Jewish section of a major cemetery in the ...
# 1     The billionaire investorBill Ackmantook aim at...
# 2     A 30-year veteran of the Israel Defense Forces...
# 3     Former House Speaker Nancy Pelosi is advocatin...
# 4     In Pictures At Lebanon’s border with Israel, r...
# ...                                                 ...
# 4846  Space-based solar power for Earth At this week...
# 4847  Defence Secretary Grant Shapps met virtually w...
# 4848   Rapala VMC Corporation, Financial calendar, N...
# 4849  Pharming Group (NASDAQ:PHAR–Get Free Report)’s...
# 4850  Aquis Exchange (LON:AQX–Get Free Report)‘s sto...
#
#                                    preprocessed_content
# 0     jewish section major cemeteri austrian capit s...
# 1     billionair investorbil ackmantook aim univers ...
# 2     veteran israel defens forc former head countri...
# 3     former hous speaker nanci pelosi advoc thirdpa...
# 4     pictur lebanon border israel resid christian v...
# ...                                                 ...
# 4846  spacebas solar power earth week climat chang c...
# 4847  defenc secretari grant shapp met virtual minis...
# 4848  rapala vmc corpor financi calendar novemb eet ...
# 4849  pharm group free report share price gap market...
# 4850  aqui exchang free report stock buy rate restat...
#
# [4851 rows x 5 columns]

# %% [markdown]
# 1. With stopwords (tutorial vectorizer)

# %%
from sentence_transformers import SentenceTransformer
from umap import UMAP
from hdbscan import HDBSCAN

embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
umap_model = UMAP(n_neighbors=15, n_components=5, min_dist=0.05, random_state=100)
hdbscan_model = HDBSCAN(min_cluster_size=80, min_samples=40,
                        gen_min_span_tree=True,
                        prediction_data=True)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
import spacy

stopwords = list(stopwords.words('english')) + ['said', "year", "also"]

# we add this to remove stopwords that can pollute topcs
vectorizer_model = CountVectorizer(ngram_range=(1, 2), stop_words=stopwords)

# %%
def lemmatize_and_remove_numbers(text):
    # Tokenize the text
    tokens = word_tokenize(text)

    # Lemmatize specific words and remove numbers
    lemmatized_tokens = []
    for token in tokens:
        token_lower = token.lower()
        if token_lower in ['israel', 'israeli']:
            lemmatized_tokens.append('israel')
        elif token_lower in ['russia', 'russian']:
            lemmatized_tokens.append('russia')
        elif token_lower in ['ukraine', 'ukrainian']:
            lemmatized_tokens.append('ukraine')
        elif not re.fullmatch(r'\d+', token):  # Regex to remove numbers
            lemmatized_tokens.append(token)

    # Reconstruct the text
    return ' '.join(lemmatized_tokens)
# Apply the function to the 'processed_text_v2' column
df['full_content'] = df['full_content'].apply(lemmatize_and_remove_numbers)

# %%
from bertopic import BERTopic

model = BERTopic(
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    embedding_model=embedding_model,
    vectorizer_model=vectorizer_model,
    top_n_words=5,
    language='english',
    calculate_probabilities=True,
    verbose=True
)
topics, probs = model.fit_transform(df['full_content'])
# Out:
# 2023-12-06 15:51:52,569 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/152 [00:00<?, ?it/s]
# 2023-12-06 16:07:33,851 - BERTopic - Embedding - Completed ✓
# 2023-12-06 16:07:33,854 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2023-12-06 16:07:46,802 - BERTopic - Dimensionality - Completed ✓
# 2023-12-06 16:07:46,805 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2023-12-06 16:07:47,230 - BERTopic - Cluster - Completed ✓
# 2023-12-06 16:07:47,240 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 2023-12-06 16:08:16,529 - BERTopic - Representation - Completed ✓

# %%
model.get_topic_info()
# Out:
#     Topic  Count                               Name  \
# 0      -1   1046        -1_people_israel_news_would
# 1       0    700   0_ukraine_russia_military_forces
# 2       1    684     1_shares_stock_company_quarter
# 3       2    583    2_climate_change_water_november
# 4       3    548    3_israel_gaza_hamas_palestinian
# 5       4    358            4_media_news_new_google
# 6       5    211     5_trump_biden_house_republican
# 7       6    201  6_court_state_election_government
# 8       7    148        7_film_marvel_season_series
# 9       8    143        8_people_police_jail_israel
# 10      9    134          9_china_chinese_xi_taiwan
# 11     10     95       10_film_updates_shared_actor
#
#                                      Representation  \
# 0                [people, israel, news, would, new]
# 1          [ukraine, russia, military, forces, war]
# 2         [shares, stock, company, quarter, rating]
# 3        [climate, change, water, november, global]
# 4           [israel, gaza, hamas, palestinian, war]
# 5               [media, news, new, google, digital]
# 6      [trump, biden, house, republican, president]
# 7   [court, state, election, government, elections]
# 8              [film, marvel, season, series, star]
# 9         [people, police, jail, israel, mattingly]
# 10              [china, chinese, xi, taiwan, biden]
# 11             [film, updates, shared, actor, khan]
#
#                                   Representative_Docs
# 0   [One of the most startling scientific discover...
# 1   [People 's Daily Online ( Xinhua ) 13:57 , Nov...
# 2   [Prudent Man Advisors LLC lessened its positio...
# 3   [Climate change is affecting practically every...
# 4   [As the Israel-Hamas war enters the 39th day ,...
# 5   [The early years sector—nurseries and childmin...
# 6   [As Republicans attempt to once again elect a ...
# 7   [The Deputy Director of the Socio-Economic Rig...
# 8   [This week brings the eighth and final episode...
# 9   [A debate over the war between israel and Hama...
# 10  [U.S. President Joe Biden greets China 's Pres...
# 11  [Shah Rukh Khan celebrated his 58th birthday o...

# %%
model.visualize_barchart(top_n_topics=12)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b962aabe-71f3-42b9-abd8-980c4e1f0ebf" class="plotly-graph-div" style="height:750px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b962aabe-71f3-42b9-abd8-980c4e1f0ebf")) {                    Plotly.newPlot(                        "b962aabe-71f3-42b9-abd8-980c4e1f0ebf",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.011152294893524891,0.011908527297496186,0.01444905775625923,0.048396104955657396,0.05338102421998557],"y":["forces  ","war  ","military  ","russia  ","ukraine  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.02561569872216213,0.03790080293683537,0.03947453846516352,0.0401698159856041,0.053086612179768906],"y":["rating  ","quarter  ","company  ","stock  ","shares  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.008704409417554881,0.009261158213429715,0.009578430639058978,0.010264137107591815,0.020096420121306958],"y":["global  ","november  ","water  ","change  ","climate  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.013225122935430824,0.018476484256166614,0.02761347106243729,0.03522737955608955,0.05806072443570353],"y":["war  ","palestinian  ","hamas  ","gaza  ","israel  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.007550183160017964,0.007929803072888673,0.008554269312767569,0.00896980972404009,0.009482386030115282],"y":["apple  ","digital  ","new  ","news  ","media  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.01289815055001401,0.014542541345771477,0.015517897340723794,0.015694360001587013,0.03417324595360314],"y":["president  ","republican  ","house  ","biden  ","trump  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.014303732944017456,0.01616747255720919,0.016749290622143333,0.02028521254659228,0.02077480193656775],"y":["elections  ","government  ","election  ","court  ","state  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.012130292194459897,0.013171015981155621,0.015055806005228302,0.015062996929611942,0.016848579835950107],"y":["mattingly  ","israel  ","jail  ","police  ","people  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.01520162838441575,0.019221158773180612,0.02034315949948687,0.02056904215511215,0.04601530934847923],"y":["biden  ","taiwan  ","xi  ","chinese  ","china  "],"type":"bar","xaxis":"x9","yaxis":"y9"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.015394488588330158,0.015412776282312862,0.015985158137597766,0.017459626094765385,0.019733487378668913],"y":["star  ","series  ","season  ","marvel  ","film  "],"type":"bar","xaxis":"x10","yaxis":"y10"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.019299311714069817,0.02048077803411914,0.0213657322811174,0.02220441770918533,0.03761302392838981],"y":["khan  ","actor  ","shared  ","updates  ","film  "],"type":"bar","xaxis":"x11","yaxis":"y11"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minor ...

# %%
model.visualize_term_rank()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="982f46c7-b43d-48ce-b818-db4e23c18001" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("982f46c7-b43d-48ce-b818-db4e23c18001")) {                    Plotly.newPlot(                        "982f46c7-b43d-48ce-b818-db4e23c18001",                        [{"hovertext":"\u003cb\u003eTopic -1\u003c\u002fb\u003e:people_israel_news_new_would","line":{"color":"black","width":1.5},"mode":"lines+lines","name":"","opacity":0.1,"x":[1,2,3,4,5],"y":[0.007959508755627846,0.007918957649217176,0.006857921689229019,0.006709293943708275,0.006340508854298908],"type":"scatter"},{"hovertext":"\u003cb\u003eTopic 0\u003c\u002fb\u003e:ukraine_russia_military_war_forces","line":{"color":"black","width":1.5},"mode":"lines+lines","name":"","opacity":0.1,"x":[1,2,3,4,5],"y":[0.05338102421998557,0.048396104955657396,0.01444905775625923,0.011908527297496186,0.011152294893524891],"type":"scatter"},{"hovertext":"\u003cb\u003eTopic 1\u003c\u002fb\u003e:shares_stock_company_quarter_rating","line":{"color":"black","width":1.5},"mode":"lines+lines","name":"","opacity":0.1,"x":[1,2,3,4,5],"y":[0.053086612179768906,0.0401698159856041,0.03947453846516352,0.03790080293683537,0.02561569872216213],"type":"scatter"},{"hovertext":"\u003cb\u003eTopic 2\u003c\u002fb\u003e:climate_change_water_november_globa","line":{"color":"black","width":1.5},"mode":"lines+lines","name":"","opacity":0.1,"x":[1,2,3,4,5],"y":[0.020096420121306958,0.010264137107591815,0.009578430639058978,0.009261158213429715,0.008704409417554881],"type":"scatter"},{"hovertext":"\u003cb\u003eTopic 3\u003c\u002fb\u003e:israel_gaza_hamas_palestinian_war","line":{"color":"black","width":1.5},"mode":"lines+lines","name":"","opacity":0.1,"x":[1,2,3,4,5],"y":[0.05806072443570353,0.03522737955608955,0.02761347106243729,0.018476484256166614,0.013225122935430824],"type":"scatter"},{"hovertext":"\u003cb\u003eTopic 4\u003c\u002fb\u003e:media_news_new_digital_apple","line":{"color":"black","width":1.5},"mode":"lines+lines","name":"","opacity":0.1,"x":[1,2,3,4,5],"y":[0.009482386030115282,0.00896980972404009,0.008554269312767569,0.007929803072888673,0.007550183160017964],"type":"scatter"},{"hovertext":"\u003cb\u003eTopic 5\u003c\u002fb\u003e:trump_biden_house_republican_presid","line":{"color":"black","width":1.5},"mode":"lines+lines","name":"","opacity":0.1,"x":[1,2,3,4,5],"y":[0.03417324595360314,0.015694360001587013,0.015517897340723794,0.014542541345771477,0.01289815055001401],"type":"scatter"},{"hovertext":"\u003cb\u003eTopic 6\u003c\u002fb\u003e:state_court_election_government_ele","line":{"color":"black","width":1.5},"mode":"lines+lines","name":"","opacity":0.1,"x":[1,2,3,4,5],"y":[0.02077480193656775,0.02028521254659228,0.016749290622143333,0.01616747255720919,0.014303732944017456],"type":"scatter"},{"hovertext":"\u003cb\u003eTopic 7\u003c\u002fb\u003e:people_police_jail_israel_mattingly","line":{"color":"black","width":1.5},"mode":"lines+lines","name":"","opacity":0.1,"x":[1,2,3,4,5],"y":[0.016848579835950107,0.015062996929611942,0.015055806005228302,0.013171015981155621,0.012130292194459897],"type":"scatter"},{"hovertext":"\u003cb\u003eTopic 8\u003c\u002fb\u003e:china_chinese_xi_taiwan_biden","line":{"color":"black","width":1.5},"mode":"lines+lines","name":"","opacity":0.1,"x":[1,2,3,4,5],"y":[0.04601530934847923,0.02056904215511215,0.02034315949948687,0.019221158773180612,0.01520162838441575],"type":"scatter"},{"hovertext":"\u003cb\u003eTopic 9\u003c\u002fb\u003e:film_marvel_season_series_star","line":{"color":"black","width":1.5},"mode":"lines+lines","name":"","opacity":0.1,"x":[1,2,3,4,5],"y":[0.019733487378668913,0.017459626094765385,0.015985158137597766,0.015412776282312862,0.015394488588330158],"t ...

# %%
# Visualize intertopic distance
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="16b11d14-7d70-447d-bfae-2973d6ecf6c9" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16b11d14-7d70-447d-bfae-2973d6ecf6c9")) {                    Plotly.newPlot(                        "16b11d14-7d70-447d-bfae-2973d6ecf6c9",                        [{"customdata":[[0,"ukraine | russia | military | war | forces",731],[1,"shares | stock | company | quarter | rating",689],[2,"climate | change | water | november | global",639],[3,"israel | gaza | hamas | palestinian | war",553],[4,"media | news | new | digital | apple",382],[5,"trump | biden | house | republican | president",229],[6,"state | court | election | government | elections",212],[7,"people | police | jail | israel | mattingly",141],[8,"china | chinese | xi | taiwan | biden",135],[9,"film | marvel | season | series | star",122],[10,"film | updates | shared | actor | khan",89]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[731,689,639,553,382,229,212,141,135,122,89],"sizemode":"area","sizeref":0.456875,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-3.0973734855651855,-3.6349575519561768,13.66408634185791,-2.808159112930298,-4.092162609100342,-1.903319001197815,-5.799380302429199,-2.2338836193084717,13.411620140075684,-4.782622814178467,-5.296433448791504],"xaxis":"x","y":[-16.503814697265625,14.867231369018555,12.903743743896484,-16.702281951904297,14.761406898498535,-16.047874450683594,15.2008056640625,-16.3416748046875,12.651208877563477,15.11954116821289,15.317325592041016],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#268 ...

# %%
model.visualize_hierarchy(top_n_topics=10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9facebe4-75cb-40fd-ae32-ed426c14a33d" class="plotly-graph-div" style="height:350px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9facebe4-75cb-40fd-ae32-ed426c14a33d")) {                    Plotly.newPlot(                        "9facebe4-75cb-40fd-ae32-ed426c14a33d",                        [{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.5869568265384093,0.5869568265384093,0.0],"xaxis":"x","y":[-15.0,-15.0,-25.0,-25.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.6152727104858013,0.6152727104858013,0.0],"xaxis":"x","y":[-35.0,-35.0,-45.0,-45.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.5869568265384093,0.7710163272965096,0.7710163272965096,0.6152727104858013],"xaxis":"x","y":[-20.0,-20.0,-40.0,-40.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.5626792440447586,0.5626792440447586,0.0],"xaxis":"x","y":[-55.0,-55.0,-65.0,-65.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.7710163272965096,0.8227362317074021,0.8227362317074021,0.5626792440447586],"xaxis":"x","y":[-30.0,-30.0,-60.0,-60.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.0,0.5118620345613614,0.5118620345613614,0.0],"xaxis":"x","y":[-75.0,-75.0,-85.0,-85.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.5118620345613614,0.7289003245899223,0.7289003245899223,0.0],"xaxis":"x","y":[-80.0,-80.0,-95.0,-95.0],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(61,153,112)"},"mode":"lines","x":[0.8227362317074021,0.8252683951015033,0.8252683951015033,0.7289003245899223],"xaxis":"x","y":[-45.0,-45.0,-87.5,-87.5],"yaxis":"y","type":"scatter"},{"hoverinfo":"text","marker":{"color":"rgb(0,116,217)"},"mode":"lines","x":[0.0,1.019585738272192,1.019585738272192,0.8252683951015033],"xaxis":"x","y":[-5.0,-5.0,-66.25,-66.25],"yaxis":"y","type":"scatter"}],                        {"autosize":false,"height":350,"hovermode":"closest","showlegend":false,"width":1000,"xaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"ticks":"outside","type":"linear","zeroline":false},"yaxis":{"mirror":"allticks","rangemode":"tozero","showgrid":false,"showline":true,"showticklabels":true,"tickmode":"array","ticks":"outside","ticktext":["1_shares_stock_company","5_trump_biden_house","6_state_court_election","8_china_chinese_xi","0_ukraine_russia_military","3_israel_gaza_hamas","7_people_police_jail","2_climate_change_water","4_media_news_new","9_film_marvel_season"],"tickvals":[-5.0,-15.0,-25.0,-35.0,-45.0,-55.0,-65.0,-75.0,-85.0,-95.0],"type":"linear","zeroline":false,"range":[-100.0,0.0]},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ti ...

# %%
model.visualize_heatmap()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c786233e-c052-42d0-ae91-7b628a15036e" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c786233e-c052-42d0-ae91-7b628a15036e")) {                    Plotly.newPlot(                        "c786233e-c052-42d0-ae91-7b628a15036e",                        [{"coloraxis":"coloraxis","name":"0","x":["0_ukraine_russia_military","1_shares_stock_company","2_climate_change_water","3_israel_gaza_hamas","4_media_news_new","5_trump_biden_house","6_state_court_election","7_people_police_jail","8_china_chinese_xi","9_film_marvel_season","10_film_updates_shared"],"y":["0_ukraine_russia_military","1_shares_stock_company","2_climate_change_water","3_israel_gaza_hamas","4_media_news_new","5_trump_biden_house","6_state_court_election","7_people_police_jail","8_china_chinese_xi","9_film_marvel_season","10_film_updates_shared"],"z":[[1.000000238418579,0.1458553522825241,0.25887396931648254,0.5604328513145447,0.3646477460861206,0.37789785861968994,0.3069802522659302,0.4762973487377167,0.4475361704826355,0.12409087270498276,0.18684367835521698],[0.1458553522825241,0.9999998211860657,0.2657676041126251,0.1052796021103859,0.4615636467933655,0.13859325647354126,0.07344869524240494,0.07665910571813583,0.1603909581899643,0.17452409863471985,0.06932725757360458],[0.25887396931648254,0.2657676041126251,1.0000001192092896,0.27064621448516846,0.47868502140045166,0.2585286796092987,0.24969600141048431,0.21036359667778015,0.4878891110420227,0.22171930968761444,0.12097857892513275],[0.5604328513145447,0.1052796021103859,0.27064621448516846,0.9999998807907104,0.3848930895328522,0.35274893045425415,0.36410990357398987,0.704547107219696,0.4401571750640869,0.19305917620658875,0.2536514401435852],[0.3646477460861206,0.4615636467933655,0.47868502140045166,0.3848930895328522,1.0000001192092896,0.4573805332183838,0.29877787828445435,0.4083649516105652,0.437644898891449,0.49672120809555054,0.3366970717906952],[0.37789785861968994,0.13859325647354126,0.2585286796092987,0.35274893045425415,0.4573805332183838,0.9999998807907104,0.44739997386932373,0.5297548770904541,0.4121783375740051,0.3230621814727783,0.19578608870506287],[0.3069802522659302,0.07344869524240494,0.24969600141048431,0.36410990357398987,0.29877787828445435,0.44739997386932373,0.9999998807907104,0.38101014494895935,0.4385010004043579,0.18441516160964966,0.5827232599258423],[0.4762973487377167,0.07665910571813583,0.21036359667778015,0.704547107219696,0.4083649516105652,0.5297548770904541,0.38101014494895935,1.000000238418579,0.3055131733417511,0.28805992007255554,0.31434375047683716],[0.4475361704826355,0.1603909581899643,0.4878891110420227,0.4401571750640869,0.437644898891449,0.4121783375740051,0.4385010004043579,0.3055131733417511,1.000000238418579,0.23127326369285583,0.32529589533805847],[0.12409087270498276,0.17452409863471985,0.22171930968761444,0.19305917620658875,0.49672120809555054,0.3230621814727783,0.18441516160964966,0.28805992007255554,0.23127326369285583,0.9999998807907104,0.5494180917739868],[0.18684367835521698,0.06932725757360458,0.12097857892513275,0.2536514401435852,0.3366970717906952,0.19578608870506287,0.5827232599258423,0.31434375047683716,0.32529589533805847,0.5494180917739868,0.9999999403953552]],"type":"heatmap","xaxis":"x","yaxis":"y","hovertemplate":"x: %{x}\u003cbr\u003ey: %{y}\u003cbr\u003eSimilarity Score: %{z}\u003cextra\u003e\u003c\u002fextra\u003e"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666 ...
